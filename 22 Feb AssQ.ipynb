# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#Question 1
l=[4,8,15,16,23,42]
pd.Series(l)

# %%
#Question 2
l=[4,8,15,16,23,42,13,14,12,11]
pd.Series(l)

# %%
#Question 3
df=pd.DataFrame({'Name':['Alice','Bob','Claire'],'Age':[25,30,27],'Gender':['Female','Male','Female']})
df

# %% [markdown]
# #Question 4
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
# It is different from pandas series because series in pandas is somewhat like list in python and is used to only store a single column or row of data.

# %% [markdown]
# #Questin 6
# Data Structure  Data        Size
# Series          Mutable     Immutable
# Data Frame      Mutable     Mutable
# Panel           Mutable     Mutable

# %%
#Question 7
la=pd.Series(['Name'])
lb=pd.Series(['Ankush','Roshni'])
d=pd.concat()
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6c40bb6c2843> in <cell line: 4>()
#       2 la=pd.Series(['Name'])
#       3 lb=pd.Series(['Ankush','Roshni'])
# ----> 4 d=pd.DataFrame({la:lb})
#       5 d
#
# TypeError: unhashable type: 'Series'
